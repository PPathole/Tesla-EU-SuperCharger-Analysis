# %%
import pandas as pd
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
data = pd.read_csv('output2.csv')

# %%
data.head(50)
# Out:
#     location.latitude  location.longitude  \
# 0           50.583368            3.089888
# 1           46.577341            4.899538
# 2           51.671308            5.602670
# 3           51.094988            4.011808
# 4           45.167240            1.483119
# 5           46.378453            2.586523
# 6           49.163980           -0.424802
# 7           43.389217           -5.803677
# 8           49.359721            0.817754
# 9           45.467532            8.462232
# 10          47.271749            5.043485
# 11          43.892580            8.039121
# 12          49.787019            3.335626
# 13          45.655436            6.365683
# 14          47.865293           11.790743
# 15          45.412326           10.970212
# 16          53.630500           -2.692696
# 17          47.817073           12.120631
# 18          47.728372           11.361923
# 19          46.682284           14.678985
# 20          52.404698           -4.064559
# 21          51.687636           -0.223596
# 22          53.507374           11.096817
# 23          47.923424           10.208663
# 24          45.524971            5.976568
# 25          47.017390            8.301470
# 26          59.112402           10.108727
# 27          50.588724            4.308133
# 28          53.314145           -1.281904
# 29          51.911281            7.398489
# 30          48.638215            6.184349
# 31          41.389320            2.133710
# 32          52.983494            9.925521
# 33          47.559299           14.252501
# 34          45.511492            9.634821
# 35          57.814044           13.418968
# 36          46.136916            6.124300
# 37          48.754865            2.373034
# 38          59.770844           10.262148
# 39          47.500581            6.812343
# 40          44.973333            7.730113
# 41          52.650769            5.038917
# 42          50.486021            4.797235
# 43          46.144299            5.281959
# 44          51.710912            8.713781
# 45          47.310734            7.934924
# 46          51.531452           -3.140042
# 47          56.931838           12.518811
# 48          43.602450            3.919900
# 49          50.889864           11.871398
#
#                                                  name  power  \
# 0          Tesla Supercharger Lille, France - Lesquin    150
# 1                  Tesla Supercharger Tournus, France    250
# 2                Tesla Supercharger Uden, Netherlands    250
# 3                 Tesla Supercharger Lokeren, Belgium    250
# 4       Tesla Supercharger Brive-la-Gaillarde, France    250
# 5   Tesla Supercharger Montluçon, France - Aire de...    250
# 6                     Tesla Supercharger Caen, France    150
# 7                   Tesla Supercharger Lugones, Spain    250
# 8             Tesla Supercharger Bourg-Achard, France    250
# 9                 Tesla Supercharger Vicolungo, Italy    250
# 10                   Tesla Supercharger Dijon, France    250
# 11                  Tesla Supercharger Imperia, Italy    150
# 12        Tesla Supercharger Aire d'Urvillers, France    150
# 13             Tesla Supercharger Albertville, France    250
# 14                 Tesla Supercharger Weyarn, Germany    138
# 15                   Tesla Supercharger Verona, Italy    150
# 16            Tesla Supercharger Charnock Richard, UK    150
# 17              Tesla Supercharger Rosenheim, Germany    250
# 18            Tesla Supercharger Sindelsdorf, Germany    250
# 19            Tesla Supercharger Völkermarkt, Austria    250
# 20                 Tesla Supercharger Aberystwyth, UK    250
# 21                Tesla Supercharger South Mimms, UK     150
# 22            Tesla Supercharger Wittenburg, Germany     250
# 23               Tesla Supercharger Woringen, Germany    250
# 24          Tesla Supercharger Aire de l'Abis, France    250
# 25             Tesla Supercharger Kriens, Switzerland    250
# 26           Tesla Supercharger Ringdalskogen, Norway    150
# 27           Tesla Supercharger Nivelles-Sud, Belgium    150
# 28        Tesla Supercharger Woodall, UK - Southbound    125
# 29                Tesla Supercharger Nottuln, Germany    250
# 30                   Tesla Supercharger Nancy, France    150
# 31  Tesla Supercharger Barcelona - L'Illa Diagonal...    150
# 32    Tesla Supercharger Soltau, Germany - Soltau-Ost    250
# 33                 Tesla Supercharger Liezen, Austria    130
# 34                Tesla Supercharger Adda Nord, Italy    250
# 35              Tesla Supercharger Ulricehamn, Sweden    150
# 36                Tesla Supercharger Archamps, France    150
# 37                  Tesla Supercharger Thiais, France    150
# 38              Tesla Supercharger Lier North, Norway    150
# 39             Tesla Supercharger Montbéliard, France    250
# 40               Tesla Supercharger Moncalieri, Italy    150
# 41             Tesla Supercharger Hoorn, Netherlands     150
# 42                  Tesla Supercharger Namur, Belgium    250
# 43         Tesla Supercharger Bourg-en-Bresse, France    250
# 44              Tesla Supercharger Paderborn, Germany    250
# 45          Tesla Supercharger Oftringen, Switzerland    125
# 46                     Tesla Supercharger Cardiff, UK    250
# 47              Tesla Supercharger Falkenberg, Sweden    150
# 48             Tesla Supercharger Montpellier, France    250
# 49              Tesla Supercharger Hermsdorf, Germany    250
#
#                       type  stalls
# 0   SITE_TYPE_SUPERCHARGER      16
# 1   SITE_TYPE_SUPERCHARGER      20
# 2   SITE_TYPE_SUPERCHARGER      24
# 3   SITE_TYPE_SUPERCHARGER      14
# 4   SITE_TYPE_SUPERCHARGER      20
# 5   SITE_TYPE_SUPERCHARGER       8
# 6   SITE_TYPE_SUPERCHARGER      12
# 7   SITE_TYPE_SUPERCHARGER      12
# 8   SITE_TYPE_SUPERCHARGER      20
# 9   SITE_TYPE_SUPERCHARGER      12
# 10  SITE_TYPE_SUPERCHARGER      16
# 11  SITE_TYPE_SUPERCHARGER      10
# 12  SITE_TYPE_SUPERCHARGER       8
# 13  SITE_TYPE_SUPERCHARGER      16
# 14  SITE_TYPE_SUPERCHARGER      18
# 15  SITE_TYPE_SUPERCHARGER      10
# 16  SITE_TYPE_SUPERCHARGER      12
# 17  SITE_TYPE_SUPERCHARGER      12
# 18  SITE_TYPE_SUPERCHARGER      12
# 19  SITE_TYPE_SUPERCHARGER      16
# 20  SITE_TYPE_SUPERCHARGER       6
# 21  SITE_TYPE_SUPERCHARGER      12
# 22  SITE_TYPE_SUPERCHARGER      10
# 23  SITE_TYPE_SUPERCHARGER      16
# 24  SITE_TYPE_SUPERCHARGER      12
# 25  SITE_TYPE_SUPERCHARGER      12
# 26  SITE_TYPE_SUPERCHARGER      20
# 27  SITE_TYPE_SUPERCHARGER      12
# 28  SITE_TYPE_SUPERCHARGER       8
# 29  SITE_TYPE_SUPERCHARGER      16
# 30  SITE_TYPE_SUPERCHARGER       8
# 31  SITE_TYPE_SUPERCHARGER       4
# 32  SITE_TYPE_SUPERCHARGER      20
# 33  SITE_TYPE_SUPERCHARGER       8
# 34  SITE_TYPE_SUPERCHARGER       4
# 35  SITE_TYPE_SUPERCHARGER      20
# 36  SITE_TYPE_SUPERCHARGER       8
# 37  SITE_TYPE_SUPERCHARGER      12
# 38  SITE_TYPE_SUPERCHARGER       8
# 39  SITE_TYPE_SUPERCHARGER      16
# 40  SITE_TYPE_SUPERCHARGER       8
# 41  SITE_TYPE_SUPERCHARGER      12
# 42  SITE_TYPE_SUPERCHARGER      15
# 43  SITE_TYPE_SUPERCHARGER       6
# 44  SITE_TYPE_SUPERCHARGER      12
# 45  SITE_TYPE_SUPERCHARGER      14
# 46  SITE_TYPE_SUPERCHARGER       8
# 47  SITE_TYPE_SUPERCHARGER      18
# 48  SITE_TYPE_SUPERCHARGER      16
# 49  SITE_TYPE_SUPERCHARGER      12

# %%
data['name'].nunique()
# Out:
# 697

# %%
data['name'].value_counts()
# Out:
# Tesla Supercharger Lille, France - Lesquin    1
# Tesla Supercharger Randers, Denmark           1
# Tesla Supercharger Flint Mountain, UK         1
# Tesla Supercharger Adda Sud, Italy            1
# Tesla Supercharger Bad Rappenau, Germany      1
#                                              ..
# Tesla Supercharger Kitzbühel, Austria         1
# Tesla Supercharger Manchester, UK - South     1
# Tesla Supercharger Eemnes, Netherlands        1
# Tesla Supercharger Rubigen, Switzerland       1
# Tesla Supercharger Thetford, UK               1
# Name: name, Length: 697, dtype: int64

# %%
data['country'] = data['name'].str.split(',').str[-1].str.split('-').str[0].str.strip()

# %%
data.head()
# Out:
#    location.latitude  location.longitude  \
# 0          50.583368            3.089888
# 1          46.577341            4.899538
# 2          51.671308            5.602670
# 3          51.094988            4.011808
# 4          45.167240            1.483119
#
#                                             name  power  \
# 0     Tesla Supercharger Lille, France - Lesquin    150
# 1             Tesla Supercharger Tournus, France    250
# 2           Tesla Supercharger Uden, Netherlands    250
# 3            Tesla Supercharger Lokeren, Belgium    250
# 4  Tesla Supercharger Brive-la-Gaillarde, France    250
#
#                      type  stalls      country
# 0  SITE_TYPE_SUPERCHARGER      16       France
# 1  SITE_TYPE_SUPERCHARGER      20       France
# 2  SITE_TYPE_SUPERCHARGER      24  Netherlands
# 3  SITE_TYPE_SUPERCHARGER      14      Belgium
# 4  SITE_TYPE_SUPERCHARGER      20       France

# %%
data['country'].unique()
# Out:
# array(['France', 'Netherlands', 'Belgium', 'Spain', 'Italy', 'Germany',
#        'UK', 'Austria', 'Switzerland', 'Norway', 'Sweden', 'Denmark',
#        'Czech Republic', 'Croatia', 'Luxembourg', 'Slovenia',
#        'UK – North Greenwich', 'UK – France Bound Only',
#        'Tesla Supercharger Centre Tesla Paris', 'Liechtenstein'],
#       dtype=object)

# %%
data.to_csv('tesla_superchargers_eu.csv', index=False)
